# %%
pip install biopython

# %%
filename= "/home/user/Desktop/sequence.fasta"

# %%
from Bio import SeqIO

# %%
seq_object= SeqIO.read(filename, "fasta")

# %%
type(seq_object)

# %%
seq_name=seq_object.name
print(seq_name)
