# %%
dna=seq_object

def dna_to_rna(dna_string)
traduction_table= str.maketrans("T","U")
rna_string = dna_string.translate(traduction_table)
return rna_string

rna= dna_to_rna(dna)
print(f"La secuencia de ARN sería:{rna}")
