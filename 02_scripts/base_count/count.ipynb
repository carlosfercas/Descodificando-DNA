# %%
dna=seq_object
number_of nucleotides=len(dna)
print("The length of this sequence is:" , number of nucleotides)


def contar_bases(dna):
  conteo_bases=collections.Counter()
bases_adn = {'A', 'C','G','T'}
resultado = {base: conteo_bases[base] for base in bases_adn }
return resultado
print(f"Resultados para el archivo{dna}:")
if isinstance(resultados,dict):
  print(f"Adenina (A): {resultados['A']}")
    print(f"Citosina (C): {resultados['C']}")
    print(f"Guanina (G): {resultados['G']}")
    print(f"Timina (T): {resultados['T']}")
else:
    print(resultados)
